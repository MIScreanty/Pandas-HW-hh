# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
hh_data = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
hh_data
# Out:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
hh_data.isnull().sum().to_frame().T
# Out:
#    Пол, возраст  ЗП  Ищет работу на должность:  Город, переезд, командировки  \
# 0             0   0                          0                             0
#
#    Занятость  График  Опыт работы  Последнее/нынешнее место работы  \
# 0          0       0          168                                1
#
#    Последняя/нынешняя должность  Образование и ВУЗ  Обновление резюме  Авто
# 0                             2                  0                  0     0

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
# Функция для классификации образования
def classify_education(education_str):
    # Извлекаем первые три слова
    words = education_str.split()[:3]
    # Определяем категорию образования
    if 'Высшее' in words:
        return 'высшее'
    elif 'Неоконченное' in words:
        return 'неоконченное высшее'
    elif 'Среднее' in words and 'специальное' in words:
        return 'среднее специальное'
    elif 'Среднее' in words:
        return 'среднее'
    else:
        return 'Неизвестно'

# Применим функцию через apply
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(lambda x: classify_education(x))

# %%
hh_data['Образование'].nunique()
# Out:
# 4

# %%
hh_data['Образование'].value_counts()
# Out:
# Образование
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: count, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
# Разделим строку по символу ' , ' (запятая с пробелом)
split_data = hh_data['Пол, возраст'].str.split(' , ', expand=True)

# Извлечём пол (первый элемент после разделения)
hh_data['Пол'] = split_data[0].map({'Мужчина': 'М', 'Женщина': 'Ж'})

# Извлечём возраст, убираем слова 'лет' или 'год' или 'года' и конвертируем в целое число
hh_data['Возраст'] = split_data[1].str.extract(r'(\d+)').astype(int)

# %%
# Сколько процентов женских резюме представлено в наших данных?
hh_data['Пол'].value_counts(normalize=True)
# Out:
# Пол
# М    0.809293
# Ж    0.190707
# Name: proportion, dtype: float64

# %%
# Чему равен средний возраст соискателей? Ответ округлите до десятых.
hh_data['Возраст'].mean()
# Out:
# 32.19674146254246

# %%
# Удаляем столбец 'Пол, возраст' из DataFrame
hh_data.drop('Пол, возраст', axis=1, inplace=True)

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь
# Функция для преобразования опыта работы в месяцы
def get_experience(experience):
    # Преобразование входных данных в строку
    str_exp = str(experience)
    # Проверка на пропуск или значение "Не указано"
    if str_exp in ['nan', 'Не указано']:
        return np.nan
    
    # Вложенная функция для расчёта месяцев
    def get_month_from_pair(first, second):
        if 'мес' in second:
            return int(first)
        else:
            return int(first) * 12
    # Если в second встречается слово "мес" (то есть это месяцы), функция просто возвращает first 
    # как количество месяцев. Если же в second встречается что-то вроде "год" (то есть это годы),
    # то функция умножает first на 12, чтобы перевести годы в месяцы.
    
    # Разделение строки на части:
    splitted = str_exp.removeprefix('Опыт работы ').split('  ')[0].strip().split(' ')
    try:
        if len(splitted) == 2:
            return get_month_from_pair(splitted[0], splitted[1])
        else:
            return get_month_from_pair(splitted[0], splitted[1]) + get_month_from_pair(splitted[2], splitted[3])
    except:
        print(f'Exception string {str_exp}')
        return np.nan

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_experience)

# Удаляем столбец «Опыт работы»
hh_data.drop('Опыт работы', axis=1, inplace=True)

# %%
hh_data['Опыт работы (месяц)'].median()
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 
                  'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']

# Функция для извлечения города
def get_city(city):
    city = str(city).split(' ,')[0]  # Убираем лишнюю информацию после запятой
    if 'Москва' in city:
        return 'Москва'
    elif 'Санкт-Петербург' in city:
        return 'Санкт-Петербург'
    elif any(million_city in city for million_city in million_cities):
        return 'город-миллионник'
    else:
        return 'другие'

# Функция для определения готовности к переезду
def is_ready_to_relocate(info):
    info = str(info).lower()
    if "не готов к переезду" in info or "не готова к переезду" in info:
        return False
    else:
        return True

# Функция для определения готовности к командировкам
def is_ready_for_business_trip(info):
    info = str(info).lower()
    if "не готов к командировкам" in info or "не готова к командировкам" in info:
        return False
    else:
        return True

# Применяем функции для создания новых признаков
hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(get_city)
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(is_ready_to_relocate)
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(is_ready_for_business_trip)

# Удаляем столбец 'Город, переезд, командировки'
hh_data.drop('Город, переезд, командировки', axis=1, inplace=True)

# %%
hh_data['Готовность к переезду'].value_counts()
# Out:
# Готовность к переезду
# False    28719
# True     16025
# Name: count, dtype: int64

# %%
hh_data['Готовность к командировкам'].value_counts()
# Out:
# Готовность к командировкам
# True     31716
# False    13028
# Name: count, dtype: int64

# %%
# Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого.
hh_data['Город'].value_counts(normalize=True)
# Out:
# Город
# Москва              0.371469
# другие              0.353723
# город-миллионник    0.164469
# Санкт-Петербург     0.110339
# Name: proportion, dtype: float64

# %%
# Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам?
# Считаем, сколько соискателей готовы и к переезду, и к командировкам
filtered_hh_data = hh_data[(hh_data['Готовность к переезду'] == True) & (hh_data['Готовность к командировкам'] == True)]
# Считаем %% соискателей от общего числа которые готовы и к переезду, и к командировкам
len(filtered_hh_data) / len(hh_data)
# Out:
# 0.32035580189522617

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
# Список уникальных категорий для "Занятость"
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']

# Список уникальных категорий для "График"
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Преобразуем "Занятость" в One Hot Encoding
for category in employment_categories:
    hh_data[category] = hh_data['Занятость'].apply(lambda x: category in x)

# Преобразуем "График" в One Hot Encoding
for category in schedule_categories:
    hh_data[category] = hh_data['График'].apply(lambda x: category in x)

# Удаляем исходные столбцы "Занятость" и "График"
hh_data.drop(['Занятость', 'График'], axis=1, inplace=True)

# %%
# Сколько людей ищут проектную работу и волонтёрство (в обоих столбцах стоит True)?
filtered_hh_data_2 = hh_data[(hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)]
# Считаем %% соискателей от общего числа которые готовы и к переезду, и к командировкам
len(filtered_hh_data_2)
# Out:
# 436

# %%
# Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)?
filtered_hh_data_3 = hh_data[(hh_data['вахтовый метод'] == True) & (hh_data['гибкий график'] == True)]
len(filtered_hh_data_3)
# Out:
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
# Разделяем строку по пробелу
hh_data[['Сумма', 'Валюта']] = hh_data['ЗП'].str.split(' ', expand=True)
# Преобразуем "Сумма" в числовой формат
hh_data['Сумма'] = hh_data['Сумма'].astype(float)
# Преобразуем дату в обновлении резюме в нужный формат
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'], format='%d.%m.%Y %H:%M').dt.date
# Создадим дф для таблицы с наименованиями ISO и пропорциями
iso_data = {
    'Наименование валюты в данных': ['грн.', 'USD', 'EUR', 'бел.руб.', 'KGS', 'сум', 'AZN', 'KZT', 'руб.'],
    'Наименование валюты в ISO-кодировке': ['UAH', 'USD', 'EUR', 'BYN', 'KGS', 'UZS', 'AZN', 'KZT', 'RUB'],
    'Пропорция': [10, 1, 1, 1, 10, 10000, 1, 100, 1]
}
iso_df = pd.DataFrame(iso_data)
# Объединение с ISO-кодами и пропорциями
hh_data = hh_data.merge(iso_df, left_on='Валюта', right_on='Наименование валюты в данных', how='left')
# Читаем файл с данными по курсам валют
currency_df = pd.read_csv('ExchangeRates.csv', sep=',')
# Приводим дату в фолрмат даты
currency_df['date'] = pd.to_datetime(currency_df['date'], format='%d/%m/%y')
# Объединение таблицы для расчета ЗП
hh_data = hh_data.merge(currency_df, left_on=['Наименование валюты в ISO-кодировке', hh_data['Обновление резюме']],
                        right_on=['currency', currency_df['date'].dt.date], how='left')
# Заполнение курсов и пропорций для рубля
hh_data.loc[hh_data['Наименование валюты в ISO-кодировке'] == 'RUB', 'close'] = 1
# Расчет зарплаты в рублях
hh_data['ЗП (руб)'] = (hh_data['Сумма'] * hh_data['close']) / hh_data['Пропорция']

# %%
hh_data['ЗП (руб)'].median()
# Out:
# 59019.0

# %%
# Удаляем лишние столбцы
hh_data = hh_data.drop(['ЗП', 'Образование и ВУЗ', 'key_1', 'Сумма', 'Валюта', 'Наименование валюты в ISO-кодировке', 'Пропорция', 'currency', 'per', 'date', 'time', 'close', 'vol', 'proportion', 'Наименование валюты в данных'], axis=1)
hh_data['Возраст'] = hh_data['Возраст'].astype('int64')

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Построение графиков
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # Два графика рядом

# Гистограмма распределения возраста
axes[0].hist(hh_data['Возраст'], bins=15, color='skyblue', edgecolor='black')
axes[0].set_title('Распределение возраста соискателей')
axes[0].set_xlabel('Возраст')
axes[0].set_ylabel('Частота')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Коробчатая диаграмма возраста
axes[1].boxplot(hh_data['Возраст'], vert=False, patch_artist=True,
                boxprops=dict(facecolor='lightgreen', color='black'))
axes[1].set_title('Коробчатая диаграмма возраста')
axes[1].set_xlabel('Возраст')

# Оптимизация расположения
plt.tight_layout()
plt.show()

# Вычисление характеристик
mode_age = hh_data['Возраст'].mode()[0]  # Мода
min_age = hh_data['Возраст'].min()       # Минимальный возраст
max_age = hh_data['Возраст'].max()       # Максимальный возраст
age_quantiles = hh_data['Возраст'].quantile([0.25, 0.75])  # Межквартильный диапазон
print(f"Мода распределения: {mode_age}")
print(f"Минимальный возраст: {min_age}")
print(f"Максимальный возраст: {max_age}")
print(f"Межквартильный диапазон: {age_quantiles[0.25]} - {age_quantiles[0.75]}")
# Out:
# Мода распределения: 30
# Минимальный возраст: 14
# Максимальный возраст: 100
# Межквартильный диапазон: 27.0 - 36.0

# %% [markdown]
# ваши выводы по графику здесь
#
# 1. Чаще всего в поиске работы люди в возрасте 30 лет
# 2. Минимальный возраст соискателя - 14 лет, что соответствует минимальному трудовому возрасту
# 3. Максимальный возраст соискателя - 100, что маловероятно в контексте трудовой деятельности. Скорее всего это и есть аномалия
# 4. Межквартильный диапазон показывает что большинство соискателей находятся в возрасте 27 - 36 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# Построение графиков
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # Два графика рядом

# Гистограмма распределения опыта работы
axes[0].hist(hh_data['Опыт работы (месяц)'], bins=20, color='skyblue', edgecolor='black')
axes[0].set_title('Распределение опыта работы соискателей')
axes[0].set_xlabel('Опыт работы (месяц)')
axes[0].set_ylabel('Частота')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Коробчатая диаграмма опыта работы
axes[1].boxplot(hh_data['Опыт работы (месяц)'], vert=False, patch_artist=True,
                boxprops=dict(facecolor='lightgreen', color='black'))
axes[1].set_title('Коробчатая диаграмма опыта работы', fontsize=16)
axes[1].set_xlabel('Опыт работы (месяц)')

# Оптимизация расположения
plt.tight_layout()
plt.show()

# Расчёты характеристик распределения
mode_experience = hh_data['Опыт работы (месяц)'].mode()[0]  # Мода
min_experience = hh_data['Опыт работы (месяц)'].min()       # Минимальное значение
max_experience = hh_data['Опыт работы (месяц)'].max()       # Максимальное значение
quantiles = hh_data['Опыт работы (месяц)'].quantile([0.25, 0.75])  # Межквартильный диапазон

# Вывод результатов
print(f"Мода распределения: {mode_experience} месяцев")
print(f"Минимальное значение: {min_experience} месяцев")
print(f"Максимальное значение: {max_experience} месяцев")
print(f"Основной диапазон (межквартильный): {quantiles[0.25]} - {quantiles[0.75]} месяцев")
# Out:
# Мода распределения: 81.0 месяцев
# Минимальное значение: 1.0 месяцев
# Максимальное значение: 1188.0 месяцев
# Основной диапазон (межквартильный): 57.0 - 154.0 месяцев

# %%
# Проверка данных
print("Проверка данных:")
print(hh_data['Опыт работы (месяц)'].describe())  # Статистика
print(f"Количество пропусков: {hh_data['Опыт работы (месяц)'].isna().sum()}")
# Out:
# Проверка данных:
# count    44574.000000
# mean       114.418944
# std         79.047861
# min          1.000000
# 25%         57.000000
# 50%        100.000000
# 75%        154.000000
# max       1188.000000
# Name: Опыт работы (месяц), dtype: float64
# Количество пропусков: 170

# %%
# Очистка данных от пропусков
clean_data = hh_data['Опыт работы (месяц)'].dropna()

# Построение графиков
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # Два графика рядом

# Гистограмма распределения опыта работы
axes[0].hist(clean_data, bins=20, color='skyblue', edgecolor='black')
axes[0].set_title('Распределение опыта работы соискателей')
axes[0].set_xlabel('Опыт работы (месяц)')
axes[0].set_ylabel('Частота')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Коробчатая диаграмма опыта работы
axes[1].boxplot(clean_data, vert=False, patch_artist=True,
                boxprops=dict(facecolor='lightgreen', color='black'))
axes[1].set_xlim(axes[0].get_xlim())  # Устанавливаем одинаковый масштаб
axes[1].set_title('Коробчатая диаграмма опыта работы')
axes[1].set_xlabel('Опыт работы (месяц)')

# Оптимизация расположения
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
# при первом построении коробчатая диаграмма получилась пустой из-за того что у некоторых соискатьелей не указан опыт работы и значение в ячейках Nan, поэтому для построения графиков очистили данные от строчек с пропусками
#
# 1. Чаще всего опыт соискателя составляет 81 месяц
# 2. Минимальный опыт - 1 месяц
# 3. Максимальный опыт - 1188 месяцев, что согласно коробочной диаграмме отнесем к аномалии
# 4. Межквартильный диапазон показывает что большинство соискателей имеют опыт работы в диапазоне 57 - 154 месяцев

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# Построение графиков
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # Два графика рядом

# Гистограмма распределения опыта работы
axes[0].hist(hh_data['ЗП (руб)'], bins=20, color='skyblue', edgecolor='black')
axes[0].set_title('Распределение ЗП соискателей')
axes[0].set_xlabel('ЗП (руб)')
axes[0].set_ylabel('Частота')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Коробчатая диаграмма опыта работы
axes[1].boxplot(hh_data['ЗП (руб)'], vert=False, patch_artist=True,
                boxprops=dict(facecolor='lightgreen', color='black'))
axes[1].set_title('Коробчатая диаграмма ЗП', fontsize=16)
axes[1].set_xlabel('Опыт работы (месяц)')

# Оптимизация расположения
plt.tight_layout()
plt.show()

# Расчёты характеристик распределения
mode_experience = hh_data['ЗП (руб)'].mode()[0]  # Мода
min_experience = hh_data['ЗП (руб)'].min()       # Минимальное значение
max_experience = hh_data['ЗП (руб)'].max()       # Максимальное значение
quantiles = hh_data['ЗП (руб)'].quantile([0.25, 0.75])  # Межквартильный диапазон

# Вывод результатов
print(f"Мода распределения: {mode_experience} руб.")
print(f"Минимальное значение: {min_experience} руб.")
print(f"Максимальное значение: {max_experience} руб.")
print(f"Основной диапазон (межквартильный): {quantiles[0.25]} - {quantiles[0.75]} руб.")
# Out:
# Мода распределения: 50000.0 руб.
# Минимальное значение: 1.0 руб.
# Максимальное значение: 24304876.0 руб.
# Основной диапазон (межквартильный): 37082.2 - 95000.0 руб.

# %%
# Фильтрация соискателей с зарплатой > 1 миллиона рублей
high_salary_count_max = hh_data[hh_data['ЗП (руб)'] > 1000000].shape[0]

print(f"Количество соискателей с зарплатой выше 1 миллиона рублей: {high_salary_count_max}")

# Фильтрация соискателей с зарплатой < 10 000 рублей
high_salary_count_min = hh_data[hh_data['ЗП (руб)'] < 1000].shape[0]

print(f"Количество соискателей с зарплатой меньше 1000 рублей: {high_salary_count_min}")
# Out:
# Количество соискателей с зарплатой выше 1 миллиона рублей: 5
# Количество соискателей с зарплатой меньше 1000 рублей: 84

# %% [markdown]
# ваши выводы здесь
# по диаграммам очевидно, что в данных есть выбросы по больгим суммам
# соискателей, которые указали ЗП больше 1 миллиона - 5 человек, меньше 1000 руб. - 84 человека что является аномалией
#
# 1. Чаще всего указанная зп составляет 50000 руб.
# 2. Минимальная зп  - 1 руб.
# 3. Максимальная зп - 24304876.0 руб.
# 4. Межквартильный диапазон показывает что большинство соискателей указали ЗП в диапазоне 37082.2 - 95000.0 руб.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Фильтруем данные: ЗП (руб) меньше 1 миллиона рублей
filtered_hh_data = hh_data[hh_data['ЗП (руб)'] < 1_000_000]

# Группировка данных по уровню образования и расчёт медианной ЗП
median_salary_by_education = (
    filtered_hh_data.groupby('Образование')['ЗП (руб)']
    .median()
    .sort_values(ascending=False)
)

# Построение диаграммы
plt.figure(figsize=(10, 6))
median_salary_by_education.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Медианная желаемая заработная плата по уровню образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# Наибольшее значение медианной ЗП наблюдается для соискателей с уровнем образования "высшее", а наименьшее - с уровнем "среднее" и "среднее специальное". Признак уровня образования при прогнозировании уровня заработной платы важен.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Упорядочим города по медианной ЗП
ordered_cities = (
    filtered_hh_data.groupby('Город')['ЗП (руб)']
    .median()
    .sort_values(ascending=False)
    .index
)

# Построение коробчатой диаграммы
plt.figure(figsize=(12, 6))
plt.boxplot(
    [filtered_hh_data[filtered_hh_data['Город'] == city]['ЗП (руб)'] for city in ordered_cities],
    labels=ordered_cities,
    patch_artist=True,
    boxprops=dict(facecolor='skyblue', color='black'),
    medianprops=dict(color='red'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    flierprops=dict(markerfacecolor='orange', marker='o', markersize=5)
)

# Настройка графика
plt.title('Распределение желаемой заработной платы по городам')
plt.xlabel('Город')
plt.ylabel('ЗП (руб)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\redha\AppData\Local\Temp\ipykernel_1588\1374204863.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %% [markdown]
# ваши выводы здесь
#
# Их диаграммы видим, что медианные уровни желаемой заработной платы и их размах выше в городах Москва и Санкт-Петербург, поэтому признак города важен при прогнозировании заработной платы.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
# Группировка данных по признакам и расчет медианной ЗП
grouped_data = filtered_hh_data.groupby(['Готовность к переезду', 'Готовность к командировкам'], as_index=False)['ЗП (руб)'].median()

# Построение многоуровневой столбчатой диаграммы с помощью Seaborn
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Готовность к переезду', y='ЗП (руб)', hue='Готовность к командировкам', data=grouped_data, palette='Set2')

# Добавление подписей медианных значений
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}',  # Медианное значение (форматирование числа)
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Координаты для подписи
                ha='center', va='center',  # Выравнивание по центру
                fontsize=12, color='black',  # Размер шрифта и цвет
                xytext=(0, 5), textcoords='offset points')  # Отступ от столбца

# Настройка диаграммы
plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=0)

# Отображение диаграммы
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
# Создание сводной таблицы
pivot_table = hh_data.pivot_table(values='ЗП (руб)', 
                                  index='Возраст', 
                                  columns='Образование', 
                                  aggfunc='median')

# Построение тепловой карты
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt='.0f', linewidths=0.5, cbar_kws={'label': 'Медианная ЗП (руб)'})

# Настройка заголовка и подписей осей
plt.title('Тепловая карта медианной заработной платы в зависимости от возраста и образования')
plt.xlabel('Образование')
plt.ylabel('Возраст')

# Отображение тепловой карты
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# Для уровня образования среднне и среднее специальное уровень медианной зарплаты с возрастом меняется незначительно.
# Для уровня образования с категорией высшее наблюдается самый быстрый карьерный рост, интенсивность карьерного роста для соискателей в категории неоконченное высшее ниже.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
# Перевод опыта работы из месяцев в годы
hh_data['Опыт работы (годы)'] = hh_data['Опыт работы (месяц)'] / 12

# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(hh_data['Возраст'], hh_data['Опыт работы (годы)'], alpha=0.5, color='blue')

# Построение прямой, проходящей через точки (0, 0) и (100, 100)
plt.plot([0, 100], [0, 100], color='red', linestyle='--', label='Опыт работы = Возраст')

# Настройка диаграммы
plt.title('Зависимость опыта работы от возраста')
plt.xlabel('Возраст')
plt.ylabel('Опыт работы (годы)')
plt.legend()

# Отображение диаграммы
plt.tight_layout()
plt.show()

# %%
# Перевод опыта работы из месяцев в годы (если еще не сделано)
hh_data['Опыт работы (годы)'] = hh_data['Опыт работы (месяц)'] / 12

# Фильтрация точек, где опыт работы больше возраста
above_line = hh_data[hh_data['Опыт работы (годы)'] > hh_data['Возраст']]

# Подсчет количества таких точек
num_above_line = above_line.shape[0]

# Вывод результата
print(f"Количество точек, лежащих строго выше прямой: {num_above_line}")
# Out:
# Количество точек, лежащих строго выше прямой: 7

# %% [markdown]
# ваши выводы здесь
# Из жиаграммы видно что с ростом возраста у соискателей опыта больше в своем большинстве.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
duplicates_count = hh_data.duplicated().sum()
print(f"Количество полных дубликатов: {duplicates_count}")
hh_data = hh_data.drop_duplicates()
# Out:
# Количество полных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
missing_info = hh_data.isna().sum()
missing_info
# Out:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# частичная занятость                  0
# проектная работа                     0
# волонтерство                         0
# стажировка                           0
# полный день                          0
# сменный график                       0
# гибкий график                        0
# удаленная работа                     0
# вахтовый метод                       0
# ЗП (руб)                             0
# Опыт работы (годы)                 168
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
hh_data = hh_data.dropna(subset=["Последнее/нынешнее место работы", "Последняя/нынешняя должность"])

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_experience = hh_data["Опыт работы (месяц)"].median()
hh_data["Опыт работы (месяц)"].fillna(median_experience, inplace=True)

hh_data["Опыт работы (месяц)"].mean()
# Out:
# C:\Users\redha\AppData\Local\Temp\ipykernel_1588\2695577536.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hh_data["Опыт работы (месяц)"].fillna(median_experience, inplace=True)
# 114.35777573405711

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
# Сколько выбросов вы нашли?
hh_data[(hh_data["ЗП (руб)"] < 1000) | (hh_data["ЗП (руб)"] > 1_000_000)].shape[0]

# Удаляем строки, где ЗП (руб) выше 1 млн или ниже 1 тыс. (фильтруем по условию ЗП от 1000 до 1000000)
hh_data = hh_data[(hh_data["ЗП (руб)"] >= 1000) & (hh_data["ЗП (руб)"] <= 1_000_000)]

# %%
hh_data.shape
# Out:
# (44492, 24)

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
invalid_data = hh_data[hh_data["Опыт работы (годы)"] > hh_data["Возраст"]].shape[0]
print(f"Количество выбросов (в которых опыт работы в годах превышает возраст соискателя): {invalid_data}")
outliers = hh_data[hh_data['Опыт работы (месяц)']/12 >= hh_data['Возраст']]
hh_data = hh_data.drop(outliers.index)
# Out:
# Количество выбросов (в которых опыт работы в годах превышает возраст соискателя): 7

# %%
hh_data.shape
# Out:
# (44485, 24)

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь
# Логарифмическое преобразование признака "Возраст"
hh_data['log_age'] = np.log(hh_data['Возраст'])

# Построение распределения логарифмического признака
plt.figure(figsize=(10, 6))
histplot = sns.histplot(hh_data['log_age'], kde=True, bins=30, color='blue', edgecolor='k')

# Вычисляем среднее и стандартное отклонение
log_age_mean = hh_data['log_age'].mean()
log_age_std = hh_data['log_age'].std()

# Добавляем линии: среднее и границы метода трех сигм
histplot.axvline(log_age_mean, color='k', lw=2, label='Среднее')
histplot.axvline(log_age_mean - 3 * log_age_std, color='red', lw=2, linestyle='--', label='-3σ')
histplot.axvline(log_age_mean + 4 * log_age_std, color='green', lw=2, linestyle='--', label='+4σ')

# Настройки графика
plt.title("Распределение возраста в логарифмическом масштабе", fontsize=14)
plt.xlabel("Логарифм возраста", fontsize=12)
plt.ylabel("Частота", fontsize=12)
plt.legend()
plt.grid()
plt.show()

# Комментарий: Распределение асимметрично в правую сторону (положительная асимметрия).

# Поиск выбросов методом Z-отклонения
hh_data['z_score'] = (hh_data['log_age'] - log_age_mean) / log_age_std

# Условие выбросов: вне интервала [-3σ, +4σ]
outliers = hh_data[(hh_data['z_score'] < -3) | (hh_data['z_score'] > 4)]

# Удаление выбросов из данных
hh_data_cleaned = hh_data[(hh_data['z_score'] >= -3) & (hh_data['z_score'] <= 4)]

# Таблица выбросов
print("Таблица выбросов:")
print(outliers[['Возраст', 'log_age', 'z_score']])

# Возраст выбросов
outlier_ages = outliers['Возраст'].unique()
print("\nВозраст соискателей, попавших в категорию выбросов:", outlier_ages)

# Подсчёт количества выбросов
num_outliers = outliers.shape[0]

print(f"Количество выбросов, найденных методом Z-отклонений: {num_outliers}")
# Out:
# Таблица выбросов:
#        Возраст  log_age   z_score
# 31137       15  2.70805 -3.186269
# 32950       15  2.70805 -3.186269
# 33654      100  4.60517  5.027199
#
# Возраст соискателей, попавших в категорию выбросов: [ 15 100]
# Количество выбросов, найденных методом Z-отклонений: 3

# %% [markdown]
# ваш коммментарий здесь
# В ходе анализа выявлено 3 выброса, которые из выборки следует удалить.
